# %% [markdown]
# ## Binary Search

# %%
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    while low <= high:
        mid = low + (high - low) // 2
        if arr[mid] == target:
            return mid
        if arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return -1

# %%
data = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
binary_search(data, 60)
# Out:
# 5

# %%
binary_search(data, 80)
# Out:
# 7

# %%
binary_search(data, 100)
# Out:
# -1
