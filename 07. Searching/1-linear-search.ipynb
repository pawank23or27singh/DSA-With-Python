# %% [markdown]
# ## Linear Search

# %%
def linear_search(arr, target):
    for index, element in enumerate(arr):
        if element == target:
            return index
    return -1

# %%
data = [4, 6, 1, 3, -1, 10, 5, 8]

# %%
linear_search(data, -1)
# Out:
# 4

# %%
linear_search(data, 5)
# Out:
# 6

# %%
linear_search(data, 100)
# Out:
# -1
