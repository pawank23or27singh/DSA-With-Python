# %% [markdown]
# ## Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_idx = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

# %%
data = [4, 2, 7, 1, 5, 9, 10]

# %%
selection_sort(data)
# Out:
# [1, 2, 4, 5, 7, 9, 10]

# %%
data = [4, 2, 7, 1, 5, 9, 10, 3, -4]
selection_sort(data)
# Out:
# [-4, 1, 2, 3, 4, 5, 7, 9, 10]
