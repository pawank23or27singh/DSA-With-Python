# %% [markdown]
# ## Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# %%
data = [40, 55, 20, 30, 80, 25, 90, 50]

# %%
quick_sort(data)
# Out:
# [20, 25, 30, 40, 50, 55, 80, 90]
